# %% [markdown]
# # Lab 2b
#
# ## Name : Abhinav Pandey
#
# ## Roll No: AM.EN.U4AIE21088

# %%
from PIL import Image, ImageFilter

# %%
filename = "home.jpg"
with Image.open(filename) as img:
    img.load()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /home/abhinav-linux/Github/ImageProcessing/Lab2b/AIE21088_Lab2b.ipynb Cell 3 line 2
#       <a href='vscode-notebook-cell:/home/abhinav-linux/Github/ImageProcessing/Lab2b/AIE21088_Lab2b.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> filename = "home.jpg"
# ----> <a href='vscode-notebook-cell:/home/abhinav-linux/Github/ImageProcessing/Lab2b/AIE21088_Lab2b.ipynb#W2sZmlsZQ%3D%3D?line=1'>2</a> with Image.open(filename) as img:
#       <a href='vscode-notebook-cell:/home/abhinav-linux/Github/ImageProcessing/Lab2b/AIE21088_Lab2b.ipynb#W2sZmlsZQ%3D%3D?line=2'>3</a>     img.load()
#
# File ~/Github/ImageProcessing/.venv/lib/python3.10/site-packages/PIL/Image.py:3243, in open(fp, mode, formats)
#    3240     filename = fp
#    3242 if filename:
# -> 3243     fp = builtins.open(filename, "rb")
#    3244     exclusive_fp = True
#    3246 try:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'home.jpg'

# %%
import matplotlib.pyplot as plt
plt.imshow(img)

# %%
blur_img = img.filter(ImageFilter.BLUR)
plt.imshow(blur_img)

# %%
blur_img=img.filter(ImageFilter.BoxBlur(10))
plt.imshow(blur_img)

# %%
gauss_blur = img.filter(ImageFilter.GaussianBlur(10))
plt.imshow(gauss_blur)

# %%
img_gray = img.convert('L')
# img_gray_smooth = img_gray.filter(ImageFilter.SMOOTH)
edges = img_gray.filter(ImageFilter.FIND_EDGES)
plt.imshow(edges, cmap='gray')

# %%
img_gray_smooth=img_gray.filter(ImageFilter.SMOOTH)
edges_smooth=img_gray_smooth.filter(ImageFilter.FIND_EDGES)
plt.imshow(edges_smooth, cmap='gray')
